# %%
import pandas as pd

# %%
coffee=pd.read_csv('/Users/kseniaoblasova/Downloads/coffee.csv')
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee['Price']=0.0
coffee
# Out:
#           Day Coffee Type  Units Sold  Price
# 0      Monday    Espresso          25    0.0
# 1      Monday       Latte          15    0.0
# 2     Tuesday    Espresso          30    0.0
# 3     Tuesday       Latte          20    0.0
# 4   Wednesday    Espresso          35    0.0
# 5   Wednesday       Latte          25    0.0
# 6    Thursday    Espresso          40    0.0
# 7    Thursday       Latte          30    0.0
# 8      Friday    Espresso          45    0.0
# 9      Friday       Latte          35    0.0
# 10   Saturday    Espresso          45    0.0
# 11   Saturday       Latte          35    0.0
# 12     Sunday    Espresso          45    0.0
# 13     Sunday       Latte          35    0.0

# %%
import numpy as np
coffee['Price']=np.where(coffee['Coffee Type']=='Espresso', 3.99, 5.05 )
coffee
# Out:
#           Day Coffee Type  Units Sold  Price
# 0      Monday    Espresso          25   3.99
# 1      Monday       Latte          15   5.05
# 2     Tuesday    Espresso          30   3.99
# 3     Tuesday       Latte          20   5.05
# 4   Wednesday    Espresso          35   3.99
# 5   Wednesday       Latte          25   5.05
# 6    Thursday    Espresso          40   3.99
# 7    Thursday       Latte          30   5.05
# 8      Friday    Espresso          45   3.99
# 9      Friday       Latte          35   5.05
# 10   Saturday    Espresso          45   3.99
# 11   Saturday       Latte          35   5.05
# 12     Sunday    Espresso          45   3.99
# 13     Sunday       Latte          35   5.05

# %%
coffee.columns=coffee.columns.str.lower().str.replace(' ', '_')
coffee
# Out:
#           day coffee_type  units_sold  price
# 0      Monday    Espresso          25   3.99
# 1      Monday       Latte          15   5.05
# 2     Tuesday    Espresso          30   3.99
# 3     Tuesday       Latte          20   5.05
# 4   Wednesday    Espresso          35   3.99
# 5   Wednesday       Latte          25   5.05
# 6    Thursday    Espresso          40   3.99
# 7    Thursday       Latte          30   5.05
# 8      Friday    Espresso          45   3.99
# 9      Friday       Latte          35   5.05
# 10   Saturday    Espresso          45   3.99
# 11   Saturday       Latte          35   5.05
# 12     Sunday    Espresso          45   3.99
# 13     Sunday       Latte          35   5.05

# %%
coffee['revenue']=coffee['units_sold']*coffee['price']
coffee
# Out:
#           day coffee_type  units_sold  price  revenue
# 0      Monday    Espresso          25   3.99    99.75
# 1      Monday       Latte          15   5.05    75.75
# 2     Tuesday    Espresso          30   3.99   119.70
# 3     Tuesday       Latte          20   5.05   101.00
# 4   Wednesday    Espresso          35   3.99   139.65
# 5   Wednesday       Latte          25   5.05   126.25
# 6    Thursday    Espresso          40   3.99   159.60
# 7    Thursday       Latte          30   5.05   151.50
# 8      Friday    Espresso          45   3.99   179.55
# 9      Friday       Latte          35   5.05   176.75
# 10   Saturday    Espresso          45   3.99   179.55
# 11   Saturday       Latte          35   5.05   176.75
# 12     Sunday    Espresso          45   3.99   179.55
# 13     Sunday       Latte          35   5.05   176.75

# %%
coffee.loc[(coffee['units_sold']<20)&(coffee['revenue']<90)]
# Out:
#       day coffee_type  units_sold  price  revenue
# 1  Monday       Latte          15   5.05    75.75

# %%
len(coffee)
coffee.loc[len(coffee)]=['Sunday', 'Espresso', '45', '3.99', 45*3.99]
coffee
# Out:
#           day coffee_type units_sold price  revenue
# 0      Monday    Espresso         25  3.99    99.75
# 1      Monday       Latte         15  5.05    75.75
# 2     Tuesday    Espresso         30  3.99   119.70
# 3     Tuesday       Latte         20  5.05   101.00
# 4   Wednesday    Espresso         35  3.99   139.65
# 5   Wednesday       Latte         25  5.05   126.25
# 6    Thursday    Espresso         40  3.99   159.60
# 7    Thursday       Latte         30  5.05   151.50
# 8      Friday    Espresso         45  3.99   179.55
# 9      Friday       Latte         35  5.05   176.75
# 10   Saturday    Espresso         45  3.99   179.55
# 11   Saturday       Latte         35  5.05   176.75
# 12     Sunday    Espresso         45  3.99   179.55
# 13     Sunday       Latte         35  5.05   176.75
# 14     Sunday    Espresso         45  3.99   179.55

# %%
coffee.drop(index=14, inplace=True)
coffee
# Out:
#           day coffee_type units_sold price  revenue
# 0      Monday    Espresso         25  3.99    99.75
# 1      Monday       Latte         15  5.05    75.75
# 2     Tuesday    Espresso         30  3.99   119.70
# 3     Tuesday       Latte         20  5.05   101.00
# 4   Wednesday    Espresso         35  3.99   139.65
# 5   Wednesday       Latte         25  5.05   126.25
# 6    Thursday    Espresso         40  3.99   159.60
# 7    Thursday       Latte         30  5.05   151.50
# 8      Friday    Espresso         45  3.99   179.55
# 9      Friday       Latte         35  5.05   176.75
# 10   Saturday    Espresso         45  3.99   179.55
# 11   Saturday       Latte         35  5.05   176.75
# 12     Sunday    Espresso         45  3.99   179.55
# 13     Sunday       Latte         35  5.05   176.75

# %%
coffee.loc[14]=['Sunday', 'Americano', 33, 4.20, 33*4.20]
coffee
# Out:
#           day coffee_type units_sold price  revenue
# 0      Monday    Espresso         25  3.99    99.75
# 1      Monday       Latte         15  5.05    75.75
# 2     Tuesday    Espresso         30  3.99   119.70
# 3     Tuesday       Latte         20  5.05   101.00
# 4   Wednesday    Espresso         35  3.99   139.65
# 5   Wednesday       Latte         25  5.05   126.25
# 6    Thursday    Espresso         40  3.99   159.60
# 7    Thursday       Latte         30  5.05   151.50
# 8      Friday    Espresso         45  3.99   179.55
# 9      Friday       Latte         35  5.05   176.75
# 10   Saturday    Espresso         45  3.99   179.55
# 11   Saturday       Latte         35  5.05   176.75
# 12     Sunday    Espresso         45  3.99   179.55
# 13     Sunday       Latte         35  5.05   176.75
# 14     Sunday   Americano         33   4.2   138.60

# %%
coffee=coffee[coffee['coffee_type'].isin(['Latte', 'Espresso'])]
coffee
# Out:
#           day coffee_type units_sold price  revenue
# 0      Monday    Espresso         25  3.99    99.75
# 1      Monday       Latte         15  5.05    75.75
# 2     Tuesday    Espresso         30  3.99   119.70
# 3     Tuesday       Latte         20  5.05   101.00
# 4   Wednesday    Espresso         35  3.99   139.65
# 5   Wednesday       Latte         25  5.05   126.25
# 6    Thursday    Espresso         40  3.99   159.60
# 7    Thursday       Latte         30  5.05   151.50
# 8      Friday    Espresso         45  3.99   179.55
# 9      Friday       Latte         35  5.05   176.75
# 10   Saturday    Espresso         45  3.99   179.55
# 11   Saturday       Latte         35  5.05   176.75
# 12     Sunday    Espresso         45  3.99   179.55
# 13     Sunday       Latte         35  5.05   176.75

# %%
coffee.iloc[::2,1]='Americano'
coffee
# Out:
#           day coffee_type units_sold price  revenue
# 0      Monday   Americano         25  3.99    99.75
# 1      Monday       Latte         15  5.05    75.75
# 2     Tuesday   Americano         30  3.99   119.70
# 3     Tuesday       Latte         20  5.05   101.00
# 4   Wednesday   Americano         35  3.99   139.65
# 5   Wednesday       Latte         25  5.05   126.25
# 6    Thursday   Americano         40  3.99   159.60
# 7    Thursday       Latte         30  5.05   151.50
# 8      Friday   Americano         45  3.99   179.55
# 9      Friday       Latte         35  5.05   176.75
# 10   Saturday   Americano         45  3.99   179.55
# 11   Saturday       Latte         35  5.05   176.75
# 12     Sunday   Americano         45  3.99   179.55
# 13     Sunday       Latte         35  5.05   176.75

# %%
coffee['coffee_type']=coffee['coffee_type'].str.replace('Americano', 'Espresso')
coffee
# Out:
#           day coffee_type units_sold price  revenue
# 0      Monday    Espresso         25  3.99    99.75
# 1      Monday       Latte         15  5.05    75.75
# 2     Tuesday    Espresso         30  3.99   119.70
# 3     Tuesday       Latte         20  5.05   101.00
# 4   Wednesday    Espresso         35  3.99   139.65
# 5   Wednesday       Latte         25  5.05   126.25
# 6    Thursday    Espresso         40  3.99   159.60
# 7    Thursday       Latte         30  5.05   151.50
# 8      Friday    Espresso         45  3.99   179.55
# 9      Friday       Latte         35  5.05   176.75
# 10   Saturday    Espresso         45  3.99   179.55
# 11   Saturday       Latte         35  5.05   176.75
# 12     Sunday    Espresso         45  3.99   179.55
# 13     Sunday       Latte         35  5.05   176.75

# %%
coffee['cost_of_production']=0

# %%
coffee
# Out:
#           day coffee_type units_sold price  revenue  cost_of_production
# 0      Monday    Espresso         25  3.99    99.75                   0
# 1      Monday       Latte         15  5.05    75.75                   0
# 2     Tuesday    Espresso         30  3.99   119.70                   0
# 3     Tuesday       Latte         20  5.05   101.00                   0
# 4   Wednesday    Espresso         35  3.99   139.65                   0
# 5   Wednesday       Latte         25  5.05   126.25                   0
# 6    Thursday    Espresso         40  3.99   159.60                   0
# 7    Thursday       Latte         30  5.05   151.50                   0
# 8      Friday    Espresso         45  3.99   179.55                   0
# 9      Friday       Latte         35  5.05   176.75                   0
# 10   Saturday    Espresso         45  3.99   179.55                   0
# 11   Saturday       Latte         35  5.05   176.75                   0
# ...

# %%
coffee['cost_of_production']=np.where(coffee['coffee_type']=='Espresso', 1, 1.5)
coffee
# Out:
#           day coffee_type units_sold price  revenue  cost_of_production
# 0      Monday    Espresso         25  3.99    99.75                 1.0
# 1      Monday       Latte         15  5.05    75.75                 1.5
# 2     Tuesday    Espresso         30  3.99   119.70                 1.0
# 3     Tuesday       Latte         20  5.05   101.00                 1.5
# 4   Wednesday    Espresso         35  3.99   139.65                 1.0
# 5   Wednesday       Latte         25  5.05   126.25                 1.5
# 6    Thursday    Espresso         40  3.99   159.60                 1.0
# 7    Thursday       Latte         30  5.05   151.50                 1.5
# 8      Friday    Espresso         45  3.99   179.55                 1.0
# 9      Friday       Latte         35  5.05   176.75                 1.5
# 10   Saturday    Espresso         45  3.99   179.55                 1.0
# 11   Saturday       Latte         35  5.05   176.75                 1.5
# ...

# %%
coffee['profit']=coffee['revenue']-coffee['cost_of_production']
coffee
# Out:
#           day coffee_type units_sold price  revenue  cost_of_production  \
# 0      Monday    Espresso         25  3.99    99.75                 1.0
# 1      Monday       Latte         15  5.05    75.75                 1.5
# 2     Tuesday    Espresso         30  3.99   119.70                 1.0
# 3     Tuesday       Latte         20  5.05   101.00                 1.5
# 4   Wednesday    Espresso         35  3.99   139.65                 1.0
# 5   Wednesday       Latte         25  5.05   126.25                 1.5
# 6    Thursday    Espresso         40  3.99   159.60                 1.0
# 7    Thursday       Latte         30  5.05   151.50                 1.5
# 8      Friday    Espresso         45  3.99   179.55                 1.0
# 9      Friday       Latte         35  5.05   176.75                 1.5
# 10   Saturday    Espresso         45  3.99   179.55                 1.0
# 11   Saturday       Latte         35  5.05   176.75                 1.5
# ...

# %%
new_data=pd.DataFrame({'day':['Monday', 'Wednesday', 'Friday'], 
                       'coffee_type':['Americano', 'Cold Brew', 'Frapuccino'],
                       'units_sold':[11,22,34],
                       'price':[3.45, 3.99, 6.05],
                       'cost_of_production':[1.2,1.4,2]})
new_data.insert(loc=4, column='revenue', value=new_data['units_sold']*new_data['price'])

new_data
# Out:
#          day coffee_type  units_sold  price  revenue  cost_of_production
# 0     Monday   Americano          11   3.45    37.95                 1.2
# 1  Wednesday   Cold Brew          22   3.99    87.78                 1.4
# 2     Friday  Frapuccino          34   6.05   205.70                 2.0

# %%
new_data.insert(loc=len(new_data.columns), column='profit', value=new_data['revenue']-new_data['cost_of_production'])
new_data
# Out:
#          day coffee_type  units_sold  price  revenue  cost_of_production  \
# 0     Monday   Americano          11   3.45    37.95                 1.2
# 1  Wednesday   Cold Brew          22   3.99    87.78                 1.4
# 2     Friday  Frapuccino          34   6.05   205.70                 2.0
#
#    profit
# 0   36.75
# 1   86.38
# 2  203.70

# %%
coffee=pd.concat([coffee, new_data], ignore_index=True)
coffee
# Out:
#           day coffee_type units_sold price  revenue  cost_of_production  \
# 0      Monday    Espresso         25  3.99    99.75                 1.0
# 1      Monday       Latte         15  5.05    75.75                 1.5
# 2     Tuesday    Espresso         30  3.99   119.70                 1.0
# 3     Tuesday       Latte         20  5.05   101.00                 1.5
# 4   Wednesday    Espresso         35  3.99   139.65                 1.0
# 5   Wednesday       Latte         25  5.05   126.25                 1.5
# 6    Thursday    Espresso         40  3.99   159.60                 1.0
# 7    Thursday       Latte         30  5.05   151.50                 1.5
# 8      Friday    Espresso         45  3.99   179.55                 1.0
# 9      Friday       Latte         35  5.05   176.75                 1.5
# 10   Saturday    Espresso         45  3.99   179.55                 1.0
# 11   Saturday       Latte         35  5.05   176.75                 1.5
# ...

# %%
coffee.drop(coffee[coffee['coffee_type']=='Frapuccino'].index, inplace=True)
coffee
# Out:
#           day coffee_type units_sold price  revenue  cost_of_production  \
# 0      Monday    Espresso         25  3.99    99.75                 1.0
# 1      Monday       Latte         15  5.05    75.75                 1.5
# 2     Tuesday    Espresso         30  3.99   119.70                 1.0
# 3     Tuesday       Latte         20  5.05   101.00                 1.5
# 4   Wednesday    Espresso         35  3.99   139.65                 1.0
# 5   Wednesday       Latte         25  5.05   126.25                 1.5
# 6    Thursday    Espresso         40  3.99   159.60                 1.0
# 7    Thursday       Latte         30  5.05   151.50                 1.5
# 8      Friday    Espresso         45  3.99   179.55                 1.0
# 9      Friday       Latte         35  5.05   176.75                 1.5
# 10   Saturday    Espresso         45  3.99   179.55                 1.0
# 11   Saturday       Latte         35  5.05   176.75                 1.5
# ...

# %%
day_order=['Monday', 'Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
coffee['day']=pd.Categorical(coffee['day'], categories=day_order, ordered=True)
sorted_by_day=coffee.sort_values('day')
sorted_by_day
# Out:
#           day coffee_type units_sold price  revenue  cost_of_production  \
# 0      Monday    Espresso         25  3.99    99.75                 1.0
# 1      Monday       Latte         15  5.05    75.75                 1.5
# 14     Monday   Americano         11  3.45    37.95                 1.2
# 2     Tuesday    Espresso         30  3.99   119.70                 1.0
# 3     Tuesday       Latte         20  5.05   101.00                 1.5
# 4   Wednesday    Espresso         35  3.99   139.65                 1.0
# 5   Wednesday       Latte         25  5.05   126.25                 1.5
# 15  Wednesday   Cold Brew         22  3.99    87.78                 1.4
# 6    Thursday    Espresso         40  3.99   159.60                 1.0
# 7    Thursday       Latte         30  5.05   151.50                 1.5
# 8      Friday    Espresso         45  3.99   179.55                 1.0
# 9      Friday       Latte         35  5.05   176.75                 1.5
# ...

# %%
sorted_by_revenue=coffee.sort_values(by='revenue', ascending=True)
sorted_by_revenue
# Out:
#           day coffee_type units_sold price  revenue  cost_of_production  \
# 14     Monday   Americano         11  3.45    37.95                 1.2
# 1      Monday       Latte         15  5.05    75.75                 1.5
# 15  Wednesday   Cold Brew         22  3.99    87.78                 1.4
# 0      Monday    Espresso         25  3.99    99.75                 1.0
# 3     Tuesday       Latte         20  5.05   101.00                 1.5
# 2     Tuesday    Espresso         30  3.99   119.70                 1.0
# 5   Wednesday       Latte         25  5.05   126.25                 1.5
# 4   Wednesday    Espresso         35  3.99   139.65                 1.0
# 7    Thursday       Latte         30  5.05   151.50                 1.5
# 6    Thursday    Espresso         40  3.99   159.60                 1.0
# 9      Friday       Latte         35  5.05   176.75                 1.5
# 11   Saturday       Latte         35  5.05   176.75                 1.5
# ...

# %%
sorted_by_day
# Out:
#           day coffee_type units_sold price  revenue  cost_of_production  \
# 0      Monday    Espresso         25  3.99    99.75                 1.0
# 1      Monday       Latte         15  5.05    75.75                 1.5
# 14     Monday   Americano         11  3.45    37.95                 1.2
# 2     Tuesday    Espresso         30  3.99   119.70                 1.0
# 3     Tuesday       Latte         20  5.05   101.00                 1.5
# 4   Wednesday    Espresso         35  3.99   139.65                 1.0
# 5   Wednesday       Latte         25  5.05   126.25                 1.5
# 15  Wednesday   Cold Brew         22  3.99    87.78                 1.4
# 6    Thursday    Espresso         40  3.99   159.60                 1.0
# 7    Thursday       Latte         30  5.05   151.50                 1.5
# 8      Friday    Espresso         45  3.99   179.55                 1.0
# 9      Friday       Latte         35  5.05   176.75                 1.5
# ...

# %%
sorted_by_day.loc[14]=['Sunday', 'Espresso', 45, 3.99, 179.55, 1.0, 178.55]
sorted_by_day
# Out:
#           day coffee_type units_sold price  revenue  cost_of_production  \
# 0      Monday    Espresso         25  3.99    99.75                 1.0
# 1      Monday       Latte         15  5.05    75.75                 1.5
# 14     Sunday    Espresso         45  3.99   179.55                 1.0
# 2     Tuesday    Espresso         30  3.99   119.70                 1.0
# 3     Tuesday       Latte         20  5.05   101.00                 1.5
# 4   Wednesday    Espresso         35  3.99   139.65                 1.0
# 5   Wednesday       Latte         25  5.05   126.25                 1.5
# 15  Wednesday   Cold Brew         22  3.99    87.78                 1.4
# 6    Thursday    Espresso         40  3.99   159.60                 1.0
# 7    Thursday       Latte         30  5.05   151.50                 1.5
# 8      Friday    Espresso         45  3.99   179.55                 1.0
# 9      Friday       Latte         35  5.05   176.75                 1.5
# ...

# %%
sorted_by_day=sorted_by_day.drop_duplicates()
sorted_by_day
# Out:
#           day coffee_type units_sold price  revenue  cost_of_production  \
# 0      Monday    Espresso         25  3.99    99.75                 1.0
# 1      Monday       Latte         15  5.05    75.75                 1.5
# 14     Sunday    Espresso         45  3.99   179.55                 1.0
# 2     Tuesday    Espresso         30  3.99   119.70                 1.0
# 3     Tuesday       Latte         20  5.05   101.00                 1.5
# 4   Wednesday    Espresso         35  3.99   139.65                 1.0
# 5   Wednesday       Latte         25  5.05   126.25                 1.5
# 15  Wednesday   Cold Brew         22  3.99    87.78                 1.4
# 6    Thursday    Espresso         40  3.99   159.60                 1.0
# 7    Thursday       Latte         30  5.05   151.50                 1.5
# 8      Friday    Espresso         45  3.99   179.55                 1.0
# 9      Friday       Latte         35  5.05   176.75                 1.5
# ...

# %%
sorted_by_day=sorted_by_day.sort_values('day')
sorted_by_day
# Out:
#           day coffee_type units_sold price  revenue  cost_of_production  \
# 0      Monday    Espresso         25  3.99    99.75                 1.0
# 1      Monday       Latte         15  5.05    75.75                 1.5
# 2     Tuesday    Espresso         30  3.99   119.70                 1.0
# 3     Tuesday       Latte         20  5.05   101.00                 1.5
# 4   Wednesday    Espresso         35  3.99   139.65                 1.0
# 5   Wednesday       Latte         25  5.05   126.25                 1.5
# 15  Wednesday   Cold Brew         22  3.99    87.78                 1.4
# 6    Thursday    Espresso         40  3.99   159.60                 1.0
# 7    Thursday       Latte         30  5.05   151.50                 1.5
# 8      Friday    Espresso         45  3.99   179.55                 1.0
# 9      Friday       Latte         35  5.05   176.75                 1.5
# 10   Saturday    Espresso         45  3.99   179.55                 1.0
# ...

# %%
sorted_by_day=sorted_by_day.reset_index(drop=True)
sorted_by_day
# Out:
#           day coffee_type units_sold price  revenue  cost_of_production  \
# 0      Monday    Espresso         25  3.99    99.75                 1.0
# 1      Monday       Latte         15  5.05    75.75                 1.5
# 2     Tuesday    Espresso         30  3.99   119.70                 1.0
# 3     Tuesday       Latte         20  5.05   101.00                 1.5
# 4   Wednesday    Espresso         35  3.99   139.65                 1.0
# 5   Wednesday       Latte         25  5.05   126.25                 1.5
# 6   Wednesday   Cold Brew         22  3.99    87.78                 1.4
# 7    Thursday    Espresso         40  3.99   159.60                 1.0
# 8    Thursday       Latte         30  5.05   151.50                 1.5
# 9      Friday    Espresso         45  3.99   179.55                 1.0
# 10     Friday       Latte         35  5.05   176.75                 1.5
# 11   Saturday    Espresso         45  3.99   179.55                 1.0
# ...

# %%
sorted_by_day.drop(columns=['level_0', 'index'], inplace=True)
sorted_by_day
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[191], line 1
# ----> 1 sorted_by_day.drop(columns=['level_0', 'index'], inplace=True)
#       2 sorted_by_day
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
# ...

# %%
coffee
# Out:
#           day coffee_type units_sold price  revenue  cost_of_production  \
# 0      Monday    Espresso         25  3.99    99.75                 1.0
# 1      Monday       Latte         15  5.05    75.75                 1.5
# 2     Tuesday    Espresso         30  3.99   119.70                 1.0
# 3     Tuesday       Latte         20  5.05   101.00                 1.5
# 4   Wednesday    Espresso         35  3.99   139.65                 1.0
# 5   Wednesday       Latte         25  5.05   126.25                 1.5
# 6    Thursday    Espresso         40  3.99   159.60                 1.0
# 7    Thursday       Latte         30  5.05   151.50                 1.5
# 8      Friday    Espresso         45  3.99   179.55                 1.0
# 9      Friday       Latte         35  5.05   176.75                 1.5
# 10   Saturday    Espresso         45  3.99   179.55                 1.0
# 11   Saturday       Latte         35  5.05   176.75                 1.5
# ...

# %%
coffee['revenue_squared']=coffee['revenue'].apply(lambda x: x**2)
coffee
# Out:
#           day coffee_type units_sold price  revenue  cost_of_production  \
# 0      Monday    Espresso         25  3.99    99.75                 1.0
# 1      Monday       Latte         15  5.05    75.75                 1.5
# 2     Tuesday    Espresso         30  3.99   119.70                 1.0
# 3     Tuesday       Latte         20  5.05   101.00                 1.5
# 4   Wednesday    Espresso         35  3.99   139.65                 1.0
# 5   Wednesday       Latte         25  5.05   126.25                 1.5
# 6    Thursday    Espresso         40  3.99   159.60                 1.0
# 7    Thursday       Latte         30  5.05   151.50                 1.5
# 8      Friday    Espresso         45  3.99   179.55                 1.0
# 9      Friday       Latte         35  5.05   176.75                 1.5
# 10   Saturday    Espresso         45  3.99   179.55                 1.0
# 11   Saturday       Latte         35  5.05   176.75                 1.5
# ...

# %%
coffee['revenue_squared']=coffee['revenue_squared'].apply(lambda x: np.sqrt(x))
coffee
# Out:
#           day coffee_type units_sold price  revenue  cost_of_production  \
# 0      Monday    Espresso         25  3.99    99.75                 1.0
# 1      Monday       Latte         15  5.05    75.75                 1.5
# 2     Tuesday    Espresso         30  3.99   119.70                 1.0
# 3     Tuesday       Latte         20  5.05   101.00                 1.5
# 4   Wednesday    Espresso         35  3.99   139.65                 1.0
# 5   Wednesday       Latte         25  5.05   126.25                 1.5
# 6    Thursday    Espresso         40  3.99   159.60                 1.0
# 7    Thursday       Latte         30  5.05   151.50                 1.5
# 8      Friday    Espresso         45  3.99   179.55                 1.0
# 9      Friday       Latte         35  5.05   176.75                 1.5
# 10   Saturday    Espresso         45  3.99   179.55                 1.0
# 11   Saturday       Latte         35  5.05   176.75                 1.5
# ...

# %%
coffee.rename(columns={'revenue_squared':'revenue'}, inplace=True)
coffee
# Out:
#           day coffee_type units_sold price  revenue  cost_of_production  \
# 0      Monday    Espresso         25  3.99    99.75                 1.0
# 1      Monday       Latte         15  5.05    75.75                 1.5
# 2     Tuesday    Espresso         30  3.99   119.70                 1.0
# 3     Tuesday       Latte         20  5.05   101.00                 1.5
# 4   Wednesday    Espresso         35  3.99   139.65                 1.0
# 5   Wednesday       Latte         25  5.05   126.25                 1.5
# 6    Thursday    Espresso         40  3.99   159.60                 1.0
# 7    Thursday       Latte         30  5.05   151.50                 1.5
# 8      Friday    Espresso         45  3.99   179.55                 1.0
# 9      Friday       Latte         35  5.05   176.75                 1.5
# 10   Saturday    Espresso         45  3.99   179.55                 1.0
# 11   Saturday       Latte         35  5.05   176.75                 1.5
# ...

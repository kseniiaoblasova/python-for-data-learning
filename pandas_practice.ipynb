# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/kseniaoblasova/Desktop/tallest_people_in_the_world.csv')
df
# Out:
#       id                 name  gender  country      continent  height_cm  \
# 0      1      John F. Carroll    Male      USA  North America        264
# 1      2        Robert Wadlow    Male      USA  North America        272
# 2      3           John Rogan    Male      USA  North America        267
# 3      4        Willie Camper    Male      USA  North America        260
# 4      5            Siah Khan    Male     Iran           Asia        259
# ..   ...                  ...     ...      ...            ...        ...
# 152  153         Jaana Kotova  Female  Estonia         Europe        210
# 153  154        Miranda Weber  Female   Canada  North America        211
# 154  155     Uljana Semjonova  Female   Latvia         Europe        213
# 155  156  Kristina Larsdotter  Female   Sweden         Europe        210
# 156  157               Han Xu  Female    China           Asia        211
#
#      height_ft_in  weight_kg  birth_year  death_year  lifespan   occupation  \
# ...

# %%
df=df.drop(columns='is_alive')
df
# Out:
#       id                 name  gender  country      continent  height_cm  \
# 0      1      John F. Carroll    Male      USA  North America        264
# 1      2        Robert Wadlow    Male      USA  North America        272
# 2      3           John Rogan    Male      USA  North America        267
# 3      4        Willie Camper    Male      USA  North America        260
# 4      5            Siah Khan    Male     Iran           Asia        259
# ..   ...                  ...     ...      ...            ...        ...
# 152  153         Jaana Kotova  Female  Estonia         Europe        210
# 153  154        Miranda Weber  Female   Canada  North America        211
# 154  155     Uljana Semjonova  Female   Latvia         Europe        213
# 155  156  Kristina Larsdotter  Female   Sweden         Europe        210
# 156  157               Han Xu  Female    China           Asia        211
#
#      height_ft_in  weight_kg  birth_year  death_year  lifespan   occupation  \
# ...

# %%
df.head(10)
# Out:
#    id                name gender   country      continent  height_cm  \
# 0   1     John F. Carroll   Male       USA  North America        264
# 1   2       Robert Wadlow   Male       USA  North America        272
# 2   3          John Rogan   Male       USA  North America        267
# 3   4       Willie Camper   Male       USA  North America        260
# 4   5           Siah Khan   Male      Iran           Asia        259
# 5   6  Akashi Shiganosuke   Male     Japan           Asia        254
# 6   7    Vrolijk de Beers   Male    Malawi         Africa        246
# 7   8        Ho Van Trung   Male   Vietnam           Asia        257
# 8   9     Pornchai Saosri   Male  Thailand           Asia        269
# 9  10       Bernard Coyne   Male       USA  North America        249
#
#   height_ft_in  weight_kg  birth_year  death_year  lifespan   occupation  \
# 0    8 ft 8 in      140.0        1932      1969.0        37          NaN
# ...

# %%
df.tail()
# Out:
#       id                 name  gender  country      continent  height_cm  \
# 152  153         Jaana Kotova  Female  Estonia         Europe        210
# 153  154        Miranda Weber  Female   Canada  North America        211
# 154  155     Uljana Semjonova  Female   Latvia         Europe        213
# 155  156  Kristina Larsdotter  Female   Sweden         Europe        210
# 156  157               Han Xu  Female    China           Asia        211
#
#      height_ft_in  weight_kg  birth_year  death_year  lifespan   occupation  \
# 152  6 ft 10.7 in        NaN        1964         NaN        62      Athlete
# 153    6 ft 11 in        NaN        1982         NaN        44      Athlete
# 154     7 ft 0 in      120.0        1952         NaN        74      Athlete
# 155  6 ft 10.7 in        NaN        1819      1854.0        35  Entertainer
# 156    6 ft 11 in       88.0        1999         NaN        27      Athlete
#
#     medical_condition
# 152           Genetic
# 153           Genetic
# ...

# %%
df.info()
df.shape
df.dtypes
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 157 non-null    int64
#  1   name               157 non-null    str
#  2   gender             157 non-null    str
#  3   country            157 non-null    str
#  4   continent          157 non-null    str
#  5   height_cm          157 non-null    int64
#  6   height_ft_in       157 non-null    str
#  7   weight_kg          74 non-null     float64
#  8   birth_year         157 non-null    int64
#  9   death_year         84 non-null     float64
#  10  lifespan           157 non-null    int64
#  11  occupation         111 non-null    str
#  12  medical_condition  157 non-null    str
# dtypes: float64(2), int64(4), str(7)
# memory usage: 16.1 KB
# id                     int64
# name                     str
# gender                   str
# country                  str
# ...

# %%
df=df.drop(columns=['height_ft_in', 'death_year'])
df
# Out:
#       id                 name  gender  country      continent  height_cm  \
# 0      1      John F. Carroll    Male      USA  North America        264
# 1      2        Robert Wadlow    Male      USA  North America        272
# 2      3           John Rogan    Male      USA  North America        267
# 3      4        Willie Camper    Male      USA  North America        260
# 4      5            Siah Khan    Male     Iran           Asia        259
# ..   ...                  ...     ...      ...            ...        ...
# 152  153         Jaana Kotova  Female  Estonia         Europe        210
# 153  154        Miranda Weber  Female   Canada  North America        211
# 154  155     Uljana Semjonova  Female   Latvia         Europe        213
# 155  156  Kristina Larsdotter  Female   Sweden         Europe        210
# 156  157               Han Xu  Female    China           Asia        211
#
#      weight_kg  birth_year  lifespan   occupation medical_condition
# ...

# %%
df.filter(regex=r'^\w+_\w+$')
# Out:
#      height_cm  weight_kg  birth_year medical_condition
# 0          264      140.0        1932        Acromegaly
# 1          272      199.0        1918         Gigantism
# 2          267       79.0        1868         Gigantism
# 3          260      170.0        1924         Gigantism
# 4          259      155.0        1913         Gigantism
# ..         ...        ...         ...               ...
# 152        210        NaN        1964           Genetic
# 153        211        NaN        1982           Genetic
# 154        213      120.0        1952           Genetic
# 155        210        NaN        1819         Gigantism
# 156        211       88.0        1999           Genetic
#
# [157 rows x 4 columns]

# %%
df.rename(columns={'height':'height_cm', 'weight':'weight_kg'}, inplace=True)
df
# Out:
#             id                 name  gender  country      continent  \
# 0    person_id      John F. Carroll    Male      USA  North America
# 1    person_id        Robert Wadlow    Male      USA  North America
# 2    person_id           John Rogan    Male      USA  North America
# 3    person_id        Willie Camper    Male      USA  North America
# 4    person_id            Siah Khan    Male     Iran           Asia
# ..         ...                  ...     ...      ...            ...
# 152  person_id         Jaana Kotova  Female  Estonia         Europe
# 153  person_id        Miranda Weber  Female   Canada  North America
# 154  person_id     Uljana Semjonova  Female   Latvia         Europe
# 155  person_id  Kristina Larsdotter  Female   Sweden         Europe
# 156  person_id               Han Xu  Female    China           Asia
#
#      height_cm  weight_kg  birth_year  lifespan   occupation medical_condition
# ...

# %%
df['person_id']=range(1, len(df)+1)
df
# Out:
#      person_id                 name  gender  country      continent  \
# 0            1      John F. Carroll    Male      USA  North America
# 1            2        Robert Wadlow    Male      USA  North America
# 2            3           John Rogan    Male      USA  North America
# 3            4        Willie Camper    Male      USA  North America
# 4            5            Siah Khan    Male     Iran           Asia
# ..         ...                  ...     ...      ...            ...
# 152        153         Jaana Kotova  Female  Estonia         Europe
# 153        154        Miranda Weber  Female   Canada  North America
# 154        155     Uljana Semjonova  Female   Latvia         Europe
# 155        156  Kristina Larsdotter  Female   Sweden         Europe
# 156        157               Han Xu  Female    China           Asia
#
#      height_cm  weight_kg  birth_year  lifespan   occupation  \
# 0          264      140.0        1932        37          NaN
# ...

# %%
df.rename(columns={'person_id':'id'}, inplace=True)
df
# Out:
#       id                 name  gender  country      continent  height_cm  \
# 0      1      John F. Carroll    Male      USA  North America        264
# 1      2        Robert Wadlow    Male      USA  North America        272
# 2      3           John Rogan    Male      USA  North America        267
# 3      4        Willie Camper    Male      USA  North America        260
# 4      5            Siah Khan    Male     Iran           Asia        259
# ..   ...                  ...     ...      ...            ...        ...
# 152  153         Jaana Kotova  Female  Estonia         Europe        210
# 153  154        Miranda Weber  Female   Canada  North America        211
# 154  155     Uljana Semjonova  Female   Latvia         Europe        213
# 155  156  Kristina Larsdotter  Female   Sweden         Europe        210
# 156  157               Han Xu  Female    China           Asia        211
#
#      weight_kg  birth_year  lifespan   occupation medical_condition         id
# ...

# %%
df=df.iloc[:,:-1]
df
# Out:
#       id                 name  gender  country      continent  height_cm  \
# 0      1      John F. Carroll    Male      USA  North America        264
# 1      2        Robert Wadlow    Male      USA  North America        272
# 2      3           John Rogan    Male      USA  North America        267
# 3      4        Willie Camper    Male      USA  North America        260
# 4      5            Siah Khan    Male     Iran           Asia        259
# ..   ...                  ...     ...      ...            ...        ...
# 152  153         Jaana Kotova  Female  Estonia         Europe        210
# 153  154        Miranda Weber  Female   Canada  North America        211
# 154  155     Uljana Semjonova  Female   Latvia         Europe        213
# 155  156  Kristina Larsdotter  Female   Sweden         Europe        210
# 156  157               Han Xu  Female    China           Asia        211
#
#      weight_kg  birth_year  lifespan   occupation medical_condition
# ...

# %%
df=df.iloc[:,:-1]
df
# Out:
#       id                 name  gender  country      continent  height_cm  \
# 0      1      John F. Carroll    Male      USA  North America        264
# 1      2        Robert Wadlow    Male      USA  North America        272
# 2      3           John Rogan    Male      USA  North America        267
# 3      4        Willie Camper    Male      USA  North America        260
# 4      5            Siah Khan    Male     Iran           Asia        259
# ..   ...                  ...     ...      ...            ...        ...
# 152  153         Jaana Kotova  Female  Estonia         Europe        210
# 153  154        Miranda Weber  Female   Canada  North America        211
# 154  155     Uljana Semjonova  Female   Latvia         Europe        213
# 155  156  Kristina Larsdotter  Female   Sweden         Europe        210
# 156  157               Han Xu  Female    China           Asia        211
#
#      weight_kg  birth_year  lifespan   occupation medical_condition
# ...

# %%
df.insert(loc=9, column='death_year', value=df['birth_year']+df['lifespan'])
df
# Out:
#       id                 name  gender  country      continent  height_cm  \
# 0      1      John F. Carroll    Male      USA  North America        264
# 1      2        Robert Wadlow    Male      USA  North America        272
# 2      3           John Rogan    Male      USA  North America        267
# 3      4        Willie Camper    Male      USA  North America        260
# 4      5            Siah Khan    Male     Iran           Asia        259
# ..   ...                  ...     ...      ...            ...        ...
# 152  153         Jaana Kotova  Female  Estonia         Europe        210
# 153  154        Miranda Weber  Female   Canada  North America        211
# 154  155     Uljana Semjonova  Female   Latvia         Europe        213
# 155  156  Kristina Larsdotter  Female   Sweden         Europe        210
# 156  157               Han Xu  Female    China           Asia        211
#
#      weight_kg  birth_year  lifespan  death_year   occupation  \
# ...

# %%
mask=df['name'].str.endswith('ova')
tall_slavics=df[mask]
print(tall_slavics)
# Out:
#       id              name  gender  country continent  height_cm  weight_kg  \
# 152  153      Jaana Kotova  Female  Estonia    Europe        210        NaN
# 154  155  Uljana Semjonova  Female   Latvia    Europe        213      120.0
#
#      birth_year  lifespan  death_year occupation medical_condition
# 152        1964        62        2026    Athlete           Genetic
# 154        1952        74        2026    Athlete           Genetic

# %%
df.loc[(df['death_year']==2026)&(df['lifespan']<100)]=None
df
# Out:
#         id                 name  gender country      continent  height_cm  \
# 0      1.0      John F. Carroll    Male     USA  North America      264.0
# 1      2.0        Robert Wadlow    Male     USA  North America      272.0
# 2      3.0           John Rogan    Male     USA  North America      267.0
# 3      4.0        Willie Camper    Male     USA  North America      260.0
# 4      5.0            Siah Khan    Male    Iran           Asia      259.0
# ..     ...                  ...     ...     ...            ...        ...
# 152    NaN                  NaN     NaN     NaN            NaN        NaN
# 153    NaN                  NaN     NaN     NaN            NaN        NaN
# 154    NaN                  NaN     NaN     NaN            NaN        NaN
# 155  156.0  Kristina Larsdotter  Female  Sweden         Europe      210.0
# 156    NaN                  NaN     NaN     NaN            NaN        NaN
#
#      weight_kg  birth_year  lifespan  death_year   occupation  \
# ...
